# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
youtube_df=pd.read_csv(r'C:\Users\Lenovo\OneDrive\Desktop\Data Science\project\Global YouTube Statistics.csv',encoding='cp1252')
youtube_df.head(5)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series  245000000.0  2.280000e+11
# 1     2              YouTube Movies  170000000.0  0.000000e+00
# 2     3                     MrBeast  166000000.0  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes  162000000.0  1.640000e+11
# 4     5                   SET India  159000000.0  1.480000e+11
#
#            category                       Title  uploads Country of origin  \
# 0             Music                    T-Series    20082             India
# 1  Film & Animation               youtubemovies        1     United States
# 2     Entertainment                     MrBeast      741     United States
# 3         Education  Cocomelon - Nursery Rhymes      966     United States
# 4             Shows                   SET India   116536             India
#
#          Country Abbreviation  ... subscribers_for_last_30_days  created_year  \
# ...

# %% [markdown]
# Data Description:
# Column Description:

# %%
youtube_df_copy=youtube_df.copy()

# %%
youtube_df_copy.drop_duplicates(inplace=True)

# %%
pd.set_option('display.max_column',None)
pd.set_option('display.max_row',None)

# %%
youtube_df_copy['Urban_population'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 995 entries, 0 to 994
# Series name: Urban_population
# Non-Null Count  Dtype
# --------------  -----
# 872 non-null    float64
# dtypes: float64(1)
# memory usage: 15.5 KB

# %%
youtube_df_copy[youtube_df_copy['Population']==youtube_df_copy['Urban_population']]
# Out:
#      rank            Youtuber  subscribers   video views        category  \
# 158   159             AboFlah   30500000.0  4.521574e+09          Gaming
# 190   191  Sandeep Maheshwari   27800000.0  2.303069e+09  People & Blogs
# 587   588                LEGO   16200000.0  2.052234e+10   Entertainment
# 619   620           MY FAMILY   15700000.0  6.153496e+09             NaN
#
#                  Title  uploads Country of origin    Country Abbreviation  \
# 158            AboFlah      641            Kuwait     Kuwait           KW
# 190  Sandeepmaheshwari        0         Singapore  Singapore           SG
# 587               LEGO    31889         Singapore  Singapore           SG
# 619          My Family      150         Singapore  Singapore           SG
#
#       channel_type  video_views_rank  country_rank  channel_type_rank  \
# 158  Entertainment            1573.0           1.0                7.0
# 190            NaN         4057944.0        3017.0                NaN
# ...

# %%
youtube_df_copy['created_month'].value_counts()
# Out:
# created_month
# Jan    100
# Sep     96
# Nov     90
# Jul     89
# Mar     86
# May     84
# Aug     81
# Oct     77
# Jun     73
# Apr     71
# Dec     69
# Feb     67
# Name: count, dtype: int64

# %%
youtube_df_copy['highest_yearly_earnings'].describe()
# Out:
# count    9.950000e+02
# mean     7.081814e+06
# std      1.379704e+07
# min      0.000000e+00
# 25%      5.217500e+05
# 50%      2.600000e+06
# 75%      7.300000e+06
# max      1.634000e+08
# Name: highest_yearly_earnings, dtype: float64

# %%
youtube_df_copy['channel_type_rank'].skew()
# Out:
# 2.7510878107164918

# %%
youtube_df_copy['channel_type_rank'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
youtube_df_copy['channel_type_rank'].plot(kind='box',grid=True)
# Out:
# <Axes: >

# %%
youtube_df_copy['lowest_yearly_earnings'].skew()
# Out:
# 4.802010892541684

# %%
youtube_df_copy['category'].value_counts()
# Out:
# category
# Entertainment            238
# Music                    201
# People & Blogs           131
# Gaming                    94
# Comedy                    69
# Education                 45
# Film & Animation          45
# Howto & Style             39
# News & Politics           26
# Science & Technology      17
# Shows                     13
# Sports                    11
# Pets & Animals             4
# Trailers                   2
# Nonprofits & Activism      2
# Movies                     2
# Autos & Vehicles           2
# Travel & Events            1
# Name: count, dtype: int64

# %%
youtube_df_copy['category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='category'>

# %%
youtube_df_copy['category'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
youtube_df_copy['category'].isnull().sum()
youtube_df_copy['channel_type'].isnull().sum()
# Out:
# 30

# %%
remove_index = youtube_df_copy[youtube_df_copy['video views']==0].index

# %%
remove_index
# Out:
# Index([1, 5, 12, 18, 102, 173, 360, 592], dtype='int64')

# %%
youtube_df_copy.drop(index=remove_index,inplace=True)

# %%
youtube_df_copy.reset_index(drop=True,inplace=True)
youtube_df_copy.head(5)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series  245000000.0  2.280000e+11
# 1     3                     MrBeast  166000000.0  2.836884e+10
# 2     4  Cocomelon - Nursery Rhymes  162000000.0  1.640000e+11
# 3     5                   SET India  159000000.0  1.480000e+11
# 4     7         ýýý Kids Diana Show  112000000.0  9.324704e+10
#
#          category                       Title  uploads Country of origin  \
# 0           Music                    T-Series    20082             India
# 1   Entertainment                     MrBeast      741     United States
# 2       Education  Cocomelon - Nursery Rhymes      966     United States
# 3           Shows                   SET India   116536             India
# 4  People & Blogs         ýýý Kids Diana Show     1111     United States
#
#          Country Abbreviation   channel_type  video_views_rank  country_rank  \
# ...

# %%
youtube_df_copy.drop(438,inplace=True)

# %%
youtube_df_copy.reset_index(drop=True,inplace=True)
youtube_df_copy.head(5)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series  245000000.0  2.280000e+11
# 1     3                     MrBeast  166000000.0  2.836884e+10
# 2     4  Cocomelon - Nursery Rhymes  162000000.0  1.640000e+11
# 3     5                   SET India  159000000.0  1.480000e+11
# 4     7         ýýý Kids Diana Show  112000000.0  9.324704e+10
#
#          category                       Title  uploads Country of origin  \
# 0           Music                    T-Series    20082             India
# 1   Entertainment                     MrBeast      741     United States
# 2       Education  Cocomelon - Nursery Rhymes      966     United States
# 3           Shows                   SET India   116536             India
# 4  People & Blogs         ýýý Kids Diana Show     1111     United States
#
#          Country Abbreviation   channel_type  video_views_rank  country_rank  \
# ...

# %%
youtube_df_copy.iloc[[895],[4]]='Entertainment'
youtube_df_copy.iloc[[895],[10]]='Entertainment'

# %%
youtube_df_copy.head(15)
# Out:
#     rank                    Youtuber  subscribers   video views  \
# 0      1                    T-Series  245000000.0  2.280000e+11
# 1      3                     MrBeast  166000000.0  2.836884e+10
# 2      4  Cocomelon - Nursery Rhymes  162000000.0  1.640000e+11
# 3      5                   SET India  159000000.0  1.480000e+11
# 4      7         ýýý Kids Diana Show  112000000.0  9.324704e+10
# 5      8                   PewDiePie  111000000.0  2.905804e+10
# 6      9                 Like Nastya  106000000.0  9.047906e+10
# 7     10               Vlad and Niki   98900000.0  7.718017e+10
# 8     11           Zee Music Company   96700000.0  5.785629e+10
# 9     12                         WWE   96000000.0  7.742847e+10
# 10    14                   BLACKPINK   89800000.0  3.214460e+10
# 11    15                   Goldmines   86900000.0  2.411823e+10
# 12    16                    Sony SAB   83000000.0  1.010000e+11
# 13    17             5-Minute Crafts   80100000.0  2.623679e+10
# ...

# %%
youtube_df_copy2=youtube_df_copy.copy()

# %%
cate_null=list(youtube_df_copy2[youtube_df_copy2['category'].isnull()].index)
cate_null
# Out:
# [10,
#  11,
#  87,
#  127,
#  150,
#  156,
#  208,
#  249,
#  250,
#  255,
#  306,
#  313,
#  326,
#  349,
#  417,
#  444,
#  487,
#  488,
#  545,
#  584,
#  589,
#  610,
#  703,
#  724,
#  726,
#  727,
#  729,
#  733,
#  754,
#  801,
#  813,
#  823,
#  840,
#  843,
#  870,
#  879,
#  898,
#  921,
#  925,
#  932,
#  941,
#  948,
#  962,
#  983]

# %%
for idx in cate_null:
    if idx in youtube_df_copy2.index:
        cht = youtube_df_copy2.loc[idx,'channel_type']
        youtube_df_copy2.loc[idx,'category']=cht
    
youtube_df_copy2.loc[cate_null,:]
# Out:
#      rank                                   Youtuber  subscribers  \
# 10     14                                  BLACKPINK   89800000.0
# 11     15                                  Goldmines   86900000.0
# 87     92                              Vlad vï¿½ï¿½ï   37900000.0
# 127   133                              BETER Bï¿½ï¿½   32700000.0
# 150   156                         Diana and Roma ESP   30700000.0
# 156   162  ýýýýýýýýýýýýýýý ýýýýýý ýýýýýýýýýýýýýýýýýý   30400000.0
# 208   215                                 D Billions   26200000.0
# 249   256                            shfa show India   24200000.0
# 250   257   Super JoJo - Nursery Rhymes & Kids Songs   24100000.0
# 255   262                         Diana and Roma ARA   24100000.0
# 306   313                       Vlad and Niki Arabic   22500000.0
# 313   320                          Vlad and Niki ESP   22000000.0
# 326   333                 ZAMZAM ELECTRONICS TRADING   21700000.0
# ...

# %%
youtube_df_copy2['category'].isnull().sum()
# Out:
# 0

# %%
ch_ty_null=list(youtube_df_copy2[youtube_df_copy2['channel_type'].isnull()].index)
ch_ty_null
# Out:
# [34,
#  53,
#  144,
#  161,
#  172,
#  177,
#  184,
#  220,
#  230,
#  334,
#  433,
#  437,
#  455,
#  460,
#  468,
#  500,
#  536,
#  540,
#  547,
#  620,
#  701,
#  769,
#  775,
#  844,
#  942,
#  960]

# %%
for idx in ch_ty_null:
    if idx in youtube_df_copy2.index:
        cat = youtube_df_copy2.loc[idx,'category']
        youtube_df_copy2.loc[idx,'channel_type']=cat
    
youtube_df_copy2.loc[ch_ty_null,:]
# Out:
#      rank                                           Youtuber  subscribers  \
# 34     39  LooLoo Kids - Nursery Rhymes and Children's Songs   54000000.0
# 53     58                                        BRIGHT SIDE   44500000.0
# 144   150                                         Luis Fonsi   31400000.0
# 161   167                                      Frost Diamond   30100000.0
# 172   179                                       Shorts Break   29000000.0
# 177   184                                     Masha y el Oso   28300000.0
# 184   191                                 Sandeep Maheshwari   27800000.0
# 220   227                                      Fede Vigevani   25600000.0
# 230   237                                        Chris Brown   25200000.0
# 334   341                                               YOLO   21400000.0
# 433   441                                     Masha e o Urso   18900000.0
# 437   445                                            Cardi B   18800000.0
# ...

# %%
youtube_df_copy=youtube_df_copy2.copy()

# %%
youtube_df_copy.loc[ch_ty_null,:]
# Out:
#      rank                                           Youtuber  subscribers  \
# 34     39  LooLoo Kids - Nursery Rhymes and Children's Songs   54000000.0
# 53     58                                        BRIGHT SIDE   44500000.0
# 144   150                                         Luis Fonsi   31400000.0
# 161   167                                      Frost Diamond   30100000.0
# 172   179                                       Shorts Break   29000000.0
# 177   184                                     Masha y el Oso   28300000.0
# 184   191                                 Sandeep Maheshwari   27800000.0
# 220   227                                      Fede Vigevani   25600000.0
# 230   237                                        Chris Brown   25200000.0
# 334   341                                               YOLO   21400000.0
# 433   441                                     Masha e o Urso   18900000.0
# 437   445                                            Cardi B   18800000.0
# ...

# %%
youtube_df_copy['video_views_rank']=youtube_df_copy['video views'].rank(method='min',ascending=False)

# %%
youtube_df_copy['rank']=youtube_df_copy['subscribers'].rank(method='min',ascending=False)

# %%
youtube_df_copy['country_rank']=youtube_df_copy.groupby('Country of origin')['subscribers'].rank(method='min',ascending=False)

# %%
# Mapping similar categories to the more frequent ones
category_mapping = {
    'People': 'People & Blogs',
    'Film': 'Film & Animation',
    'Tech': 'Science & Technology',
    'Games': 'Gaming',
    'Howto': 'Howto & Style',
    'Movies': 'Film & Animation',
}

# Replace similar categories in the DataFrame
youtube_df_copy['category'] = youtube_df_copy['category'].replace(category_mapping)
youtube_df_copy['category'].value_counts()
# Out:
# category
# Entertainment            254
# Music                    206
# People & Blogs           143
# Gaming                    98
# Comedy                    69
# Film & Animation          48
# Education                 48
# Howto & Style             40
# News & Politics           26
# Science & Technology      18
# Shows                     13
# Sports                    12
# Pets & Animals             4
# Trailers                   2
# Nonprofits & Activism      2
# Autos & Vehicles           2
# Travel & Events            1
# Name: count, dtype: int64

# %%
channel_type_mapping = {
    'People & Blogs': 'People',
    'Howto & Style': 'Howto',
    'Pets & Animals': 'Animals',
    'Film & Animation': 'Film',
    'Science & Technology': 'Tech',
    'Gaming': 'Games'
}

# Replace similar channel types in the DataFrame
youtube_df_copy['channel_type'] = youtube_df_copy['channel_type'].replace(channel_type_mapping)

# %%
youtube_df_copy['channel_type_rank']=youtube_df_copy.groupby('channel_type')['subscribers'].rank(method='min',ascending=False)

# %%
youtube_df_copy['video_views_for_the_last_30_days'].skew()
# Out:
# 8.766812953838377

# %%
youtube_df_copy['video_views_for_the_last_30_days'].interpolate(method='linear').plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ***Exploratory Data Analysis starts from here***
# #### 1.	What are the top 10 YouTube channels based on the number of subscribers?

# %%
youtube_df_copy.iloc[:10,[1,2]]
# Out:
#                      Youtuber  subscribers
# 0                    T-Series  245000000.0
# 1                     MrBeast  166000000.0
# 2  Cocomelon - Nursery Rhymes  162000000.0
# 3                   SET India  159000000.0
# 4         ýýý Kids Diana Show  112000000.0
# 5                   PewDiePie  111000000.0
# 6                 Like Nastya  106000000.0
# 7               Vlad and Niki   98900000.0
# 8           Zee Music Company   96700000.0
# 9                         WWE   96000000.0

# %%
g=sns.barplot(data=youtube_df_copy,x=youtube_df_copy.iloc[:10,[1,2]]['Youtuber'],y=youtube_df_copy.iloc[:10,[1,2]]['subscribers'],hue=youtube_df_copy.iloc[:10,[1,2]]['Youtuber'],palette='viridis',legend=False)
g.set_xticks(ticks=youtube_df_copy.iloc[:10,[1,2]]['Youtuber'])
g.set_xticklabels(labels=youtube_df_copy.iloc[:10,[1,2]]['Youtuber'],rotation=90)
plt.show()

# %% [markdown]
# #### 2.	Which category has the highest average number of subscribers?

# %%
youtube_df_copy.groupby('category')['subscribers'].mean().sort_values(ascending=False).index[0]
# Out:
# 'Shows'

# %%
youtube_df_copy.groupby('category')['subscribers'].mean().sort_values(ascending=False).plot(kind='bar',colormap='summer')
# Out:
# <Axes: xlabel='category'>

# %% [markdown]
# #### 3.	How many videos, on average, are uploaded by YouTube channels in each category?

# %%
youtube_df_copy['uploads'].isnull().sum()
# Out:
# 0

# %%
youtube_df_copy.groupby('category')['uploads'].mean().sort_values(ascending=False).plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='category'>

# %% [markdown]
# #### 5.	What is the distribution of channel types across different categories?

# %%
# Assuming youtube_df_copy is already defined
channel_types = youtube_df_copy['channel_type'].unique()
channel_types = np.delete(channel_types, 7)  # Remove the 8th channel type

youtube_palette = ["#FF0000",  # YouTube Red
                   "#282828",  # Dark Gray/Black
                   "#FFFFFF",  # White
                   "#C0C0C0"]  # Light Gray

# Create the catplot
g = sns.catplot(data=youtube_df_copy, x='channel_type', col='category', col_wrap=4, kind='count',hue='channel_type', sharex=False, sharey=False,palette='Set1',legend=False)
g.set_xticklabels(rotation=90)
g.fig.subplots_adjust(hspace=0.5)

# %%
youtube_df_copy.to_csv('youtube_stats.csv',index=False)

# %%
youtube_df_copy.drop(columns='Country',inplace=True)

# %%
youtube_df_copy2['Country of origin']=youtube_df_copy2['Country of origin'].fillna('Unknown')

# %%
youtube_df_copy['Gross tertiary education enrollment (%)'].describe()
# Out:
# count    870.000000
# mean      63.571264
# std       26.110260
# min        7.600000
# 25%       36.300000
# 50%       68.000000
# 75%       88.200000
# max      113.100000
# Name: Gross tertiary education enrollment (%), dtype: float64

# %%
youtube_df_copy['Abbreviation']=youtube_df_copy['Abbreviation'].fillna('UN')

# %%
#index - 654, rank - 652 has missing data for a country - Andorra, needs to be filled using domain knowledge
#population - 80,329
# Unemployment rate - 1.5%
# Urban Population - 70850
#Latitude - 42.5063
#Longitude -  1.5218
#Gross Tertiary education enrollment (%) - 50
youtube_df_copy.loc[654,'Gross tertiary education enrollment (%)']=50
youtube_df_copy.loc[654,'Population']=80329
youtube_df_copy.loc[654,'Urban_population']=70850
youtube_df_copy.loc[654,'Unemployment rate']=1.5
youtube_df_copy.loc[654,'Latitude']=42.5063
youtube_df_copy.loc[654,'Longitude']=1.5218

# %%
month_mapping = {
    'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
    'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12
}
youtube_df_copy=pd.read_csv('youtube_stats.csv',encoding='cp1252')

# %%
youtube_df_copy['created_month']=youtube_df_copy['created_month'].map(month_mapping)

# %%
youtube_df_copy['created_month'].value_counts()
# Out:
# created_month
# 1.0     98
# 9.0     94
# 11.0    90
# 7.0     89
# 3.0     86
# 5.0     84
# 8.0     80
# 10.0    77
# 6.0     73
# 4.0     71
# 2.0     67
# 12.0    66
# Name: count, dtype: int64

# %%
youtube_df_copy[youtube_df_copy['created_date'].isnull()]['Youtuber']

# information from the internet(available in our case)
# Chris Brown: October 10, 2005 .
# Good Mythical Morning: September 17, 2008 .
# The Game Theorists: August 22, 2009​ (Yahoo News - Latest News & Headlines)​.
# LEGENDA FUNK: May 11, 2013
# Harry Styles: December 15, 2010
# Out:
# 230              Chris Brown
# 460    Good Mythical Morning
# 500       The Game Theorists
# 726             LEGENDA FUNK
# 753             Harry Styles
# Name: Youtuber, dtype: object

# %%
youtube_df_copy.loc[230,'created_year']=2005
youtube_df_copy.loc[230,'created_month']=10
youtube_df_copy.loc[230,'created_date']=10
youtube_df_copy.loc[460,'created_year']=2008
youtube_df_copy.loc[460,'created_month']=9
youtube_df_copy.loc[460,'created_date']=17
youtube_df_copy.loc[500,'created_year']=2009
youtube_df_copy.loc[500,'created_month']=8
youtube_df_copy.loc[500,'created_date']=22
youtube_df_copy.loc[753,'created_year']=2010
youtube_df_copy.loc[753,'created_month']=10
youtube_df_copy.loc[753,'created_date']=15
youtube_df_copy.loc[726,'created_year']=2013
youtube_df_copy.loc[726,'created_month']=5
youtube_df_copy.loc[726,'created_date']=11

# %%
youtube_df_copy.fillna(value={'created_month':1},inplace=True) # most frequently appearing month when a channel is created

# %%
youtube_df_copy['created_date'].isnull().sum()
# Out:
# 0

# %%
youtube_df_copy.rename(columns={'created_year':'year','created_month':'month','created_date':'day'},inplace=True)

# %%
youtube_df_copy.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country of origin', 'Country', 'Abbreviation',
#        'channel_type', 'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days', 'year',
#        'month', 'day', 'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
youtube_df_copy['created_date']=pd.to_datetime(youtube_df_copy[['year','month','day']])

# %%
youtube_df_copy['created_date'].dt.month.value_counts()
# Out:
# created_date
# 1     104
# 9      95
# 11     90
# 7      89
# 3      86
# 5      85
# 8      81
# 10     79
# 6      73
# 4      71
# 2      67
# 12     66
# Name: count, dtype: int64

# %%
youtube_df_copy.drop(columns=['year','month','day'],inplace=True)

# %%
youtube_df_copy.head(5)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0   1.0                    T-Series  245000000.0  2.280000e+11
# 1   2.0                     MrBeast  166000000.0  2.836884e+10
# 2   3.0  Cocomelon - Nursery Rhymes  162000000.0  1.640000e+11
# 3   4.0                   SET India  159000000.0  1.480000e+11
# 4   5.0      Ã½Ã½Ã½ Kids Diana Show  112000000.0  9.324704e+10
#
#          category                       Title  uploads Country of origin  \
# 0           Music                    T-Series    20082             India
# 1   Entertainment                     MrBeast      741     United States
# 2       Education  Cocomelon - Nursery Rhymes      966     United States
# 3           Shows                   SET India   116536             India
# 4  People & Blogs      Ã½Ã½Ã½ Kids Diana Show     1111     United States
#
#          Country Abbreviation   channel_type  video_views_rank  country_rank  \
# ...

# %%
youtube_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 27 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     983 non-null    float64
#  1   Youtuber                                 986 non-null    object
#  2   subscribers                              983 non-null    float64
#  3   video views                              986 non-null    float64
#  4   category                                 986 non-null    object
#  5   Title                                    986 non-null    object
#  6   uploads                                  986 non-null    int64
#  7   Country of origin                        871 non-null    object
#  8   Country                                  871 non-null    object
#  9   Abbreviation                             871 non-null    object
# ...

# %%
youtube_df_copy['subscribers']=youtube_df_copy['subscribers'].fillna(method='ffill')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_24180\1943013470.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   youtube_df_copy['subscribers']=youtube_df_copy['subscribers'].fillna(method='ffill')

# %%
youtube_df_copy['subscribers_for_last_30_days'].describe()
# Out:
# count    6.570000e+02
# mean     3.491538e+05
# std      6.148205e+05
# min      1.000000e+00
# 25%      1.000000e+05
# 50%      2.000000e+05
# 75%      4.000000e+05
# max      8.000000e+06
# Name: subscribers_for_last_30_days, dtype: float64

# %%
#replacing 'subscribers_for_last_30_days' column values with its median
med = youtube_df_copy['subscribers_for_last_30_days'].median()

youtube_df_copy['subscribers_for_last_30_days']=youtube_df_copy['subscribers_for_last_30_days'].fillna(med)

# %% [markdown]
# ## 4.

# %%
youtube_df_copy['Country of origin'].value_counts().sort_values(ascending=False).head(5)
youtube_df_copy['Country of origin'].value_counts().sort_values(ascending=False).head(5).plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='Country of origin'>

# %% [markdown]
# ## 6.

# %%
youtube_df_copy.loc[:,['subscribers','video views']].corr('pearson')
# Out:
#              subscribers  video views
# subscribers     1.000000     0.824252
# video views     0.824252     1.000000

# %%
sns.regplot(data=youtube_df_copy,x='subscribers',y='video views',scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# <Axes: xlabel='subscribers', ylabel='video views'>

# %% [markdown]
# ## 7.

# %%
# Create a FacetGrid with KDE plots
g = sns.FacetGrid(youtube_df_copy, col='category', col_wrap=3, sharex=False)
g.map_dataframe(sns.kdeplot, x='lowest_monthly_earnings', color='green')

# Set axis labels and title
g.set_axis_labels('Lowest Monthly Earnings', 'Density')
# Out:
# c:\Users\Lenovo\OneDrive\Desktop\Data Science\.venv\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)

# %%
# Create a FacetGrid with KDE plots
g = sns.FacetGrid(youtube_df_copy, col='category', col_wrap=3, sharex=False)
g.map_dataframe(sns.kdeplot, x='highest_monthly_earnings', color='red')

# Set axis labels and title
g.set_axis_labels('Highest Monthly Earnings', 'Density')
# Out:
# c:\Users\Lenovo\OneDrive\Desktop\Data Science\.venv\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)

# %%
youtube_df_copy.groupby('category')['lowest_monthly_earnings'].skew()
# Out:
# category
# Autos & Vehicles              NaN
# Comedy                   2.180977
# Education                4.461663
# Entertainment            3.615468
# Film & Animation         4.269325
# Gaming                   5.802525
# Howto & Style            4.155704
# Music                    5.890792
# News & Politics          0.847323
# Nonprofits & Activism         NaN
# People & Blogs           5.406798
# Pets & Animals           1.981162
# Science & Technology     1.083373
# Shows                    1.342605
# Sports                   1.034833
# Trailers                      NaN
# Travel & Events               NaN
# Name: lowest_monthly_earnings, dtype: float64
